# %%
with open("open_seishin_h_east_r040610.csv", "r") as f:
    data = f.readlines()
    for line in data:
        line = line.strip().split(",")
        if line[0] == "行先駅":
            go = line[1:]
        if line[0] == "学園都市":
            time = line[1:]

times = [tuple(map(int,t.split(":"))) +  for t in time if ":" in t]
print(go,times) # 行先と時刻
# Out:
#   File "<ipython-input-1-a3846de2ff36>", line 10
#     times = [tuple(map(int,t.split(":"))) +  for t in time if ":" in t]
#                                              ^
# SyntaxError: invalid syntax

# %%
import datetime
import bisect

go = ['新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '新神戸', '谷上', '新神戸', '新神戸', '谷上', '新神戸', '谷上', '新神戸', '谷上', '名谷', '谷上', '新神戸', '谷上', '名谷', '名谷', '名谷', '名谷']
times = [(5, 29), (5, 40), (5, 52), (6, 1), (6, 14), (6, 22), (6, 37), (6, 45), (6, 56), (7, 3), (7, 10), (7, 17), (7, 23), (7, 28), (7, 35), (7, 41), (7, 48), (7, 52), (7, 57), (8, 2), (8, 8), (8, 13), (8, 17), (8, 23), (8, 30), (8, 36), (8, 43), (8, 49), (8, 54), (8, 58), (9, 4), (9, 10), (9, 18), (9, 24), (9, 29), (9, 35), (9, 43), (9, 51), (9, 58), (10, 6), (10, 13), (10, 21), (10, 29), (10, 36), (10, 44), (10, 51), (10, 59), (11, 6), (11, 14), (11, 21), (11, 29), (11, 36), (11, 44), (11, 51), (11, 59), (12, 6), (12, 14), (12, 21), (12, 29), (12, 36), (12, 44), (12, 51), (12, 59), (13, 6), (13, 14), (13, 21), (13, 29), (13, 36), (13, 44), (13, 51), (13, 59), (14, 6), (14, 14), (14, 21), (14, 29), (14, 36), (14, 44), (14, 51), (14, 59), (15, 6), (15, 14), (15, 21), (15, 29), (15, 36), (15, 44), (15, 50), (15, 58), (16, 5), (16, 14), (16, 21), (16, 29), (16, 35), (16, 43), (16, 50), (16, 58), (17, 5), (17, 13), (17, 20), (17, 27), (17, 33), (17, 40), (17, 46), (17, 54), (18, 1), (18, 7), (18, 14), (18, 23), (18, 28), (18, 37), (18, 43), (18, 51), (18, 58), (19, 6), (19, 13), (19, 21), (19, 28), (19, 34), (19, 41), (19, 48), (19, 55), (20, 3), (20, 10), (20, 18), (20, 26), (20, 33), (20, 41), (20, 49), (20, 56), (21, 5), (21, 13), (21, 23), (21, 29), (21, 38), (21, 45), (21, 53), (22, 2), (22, 8), (22, 16), (22, 22), (22, 29), (22, 39), (22, 49), (22, 59), (23, 5), (23, 13), (23, 21), (23, 32), (23, 38), (23, 47), (23, 56), (0, 9), (0, 22)]
dt = datetime.datetime.today()
now = dt.time()
now = now.hour, now.minute # 今

idx = bisect.bisect_left(times, now)
print(f"現在{now[0]}時{now[1]}分です．")
for i in range(60):
    if idx+i < len(times):
        nex = "次の"*(1)
        H,M = times[idx+i]
        print(f"{nex}電車は{H}時{M}分の{go[idx+i]}行です．")
    else:
        print(f"{nex}電車はありません.急ぎましょう")
# Out:
# 現在17時37分です．
# 次の電車は17時40分の谷上行です．
# 次の電車は17時46分の新神戸行です．
# 次の電車は17時54分の谷上行です．
# 次の電車は18時1分の新神戸行です．
# 次の電車は18時7分の谷上行です．
# 次の電車は18時14分の新神戸行です．
# 次の電車は18時23分の新神戸行です．
# 次の電車は18時28分の谷上行です．
# 次の電車は18時37分の新神戸行です．
# 次の電車は18時43分の谷上行です．
# 次の電車は18時51分の新神戸行です．
# 次の電車は18時58分の谷上行です．
# 次の電車は19時6分の新神戸行です．
# 次の電車は19時13分の谷上行です．
# 次の電車は19時21分の新神戸行です．
# 次の電車は19時28分の谷上行です．
# 次の電車は19時34分の新神戸行です．
# 次の電車は19時41分の谷上行です．
# 次の電車は19時48分の新神戸行です．
# 次の電車は19時55分の谷上行です．
# 次の電車は20時3分の新神戸行です．
# 次の電車は20時10分の谷上行です．
# 次の電車は20時18分の新神戸行です．
# 次の電車は20時26分の谷上行です．
# 次の電車は20時33分の新神戸行です．
# 次の電車は20時41分の谷上行です．
# 次の電車は20時49分の新神戸行です．
# 次の電車は20時56分の谷上行です．
# 次の電車は21時5分の新神戸行です．
# 次の電車は21時13分の谷上行です．
# 次の電車は21時23分の新神戸行です．
# 次の電車は21時29分の谷上行です．
# 次の電車は21時38分の新神戸行です．
# 次の電車は21時45分の谷上行です．
# 次の電車は21時53分の新神戸行です．
# 次の電車は22時2分の谷上行です．
# 次の電車は22時8分の新神戸行です．
# 次の電車は22時16分の新神戸行です．
# 次の電車は22時22分の谷上行です．
# 次の電車は22時29分の新神戸行です．
# 次の電車は22時39分の新神戸行です．
# 次の電車は22時49分の谷上行です．
# 次の電車は22時59分の新神戸行です．
# 次の電車は23時5分の谷上行です．
# 次の電車は23時13分の新神戸行です．
# 次の電車は23時21分の谷上行です．
# ...
